# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter21 ~ 32 수업은 잘 들으셨나요?
#
# Chapter21 ~ 32의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ---

# %% [markdown]
# [문제 1]
# 사용자로부터 이름과 나이를 입력 받아, "안녕하세요, [이름]님! 당신은 [나이]살입니다."라고 출력하는 함수 greet_user를 작성하세요.

# %%
def greet_user():
    name = input("이름을 입력하세요: ")
    age = input("나이를 입력하세요: ")
    print(f"안녕하세요, {name}님! 당신은 {age}살입니다.")
greet_user()
# Out:
# 이름을 입력하세요: 이형운
# 나이를 입력하세요: 29
# 안녕하세요, 이형운님! 당신은 29살입니다.

# %% [markdown]
# ---

# %% [markdown]
# [문제 2] 여러 숫자를 입력받아 그 합계를 반환하는 함수 sum_numbers를 작성하세요. 이 때, 가변 매개변수를 사용하세요.

# %%
def sum_numbers(*numbers):
    total = 0
    for num in numbers:
        total += int(num)
    print(total)
num_input = input("더할 숫자를 ,로 구분하여 입력하세요: ")
num_list = num_input.split(',')
sum_numbers(*num_list)
# Out:
# 더할 숫자를 ,로 구분하여 입력하세요: 30,20
# 50

# %% [markdown]
# ---

# %% [markdown]
# [문제 3] 사용자의 이름을 출력하는 함수 print_name을 작성하세요. 만약 이름이 주어지지 않았다면, 기본값으로 "익명"을 사용하세요.

# %%
def print_name():
    name = input("이름을 입력하세요: ")
    if name == "":
        name = "익명"
        print(name)

print_name()
# Out:
# 이름을 입력하세요: 형운

# %% [markdown]
# ---

# %% [markdown]
# [문제 4] 사용자의 이름, 나이, 성별을 출력하는 함수 print_info를 작성하세요. 이 때, 모든 매개변수는 키워드 매개변수로만 받도록 하세요.

# %%
def print_info(name, age, gender):
    print(f"이름:{name}, 나이:{age}, 성별:{gender}")
print_info(name = input("이름을 입력하세요:"), age = input("나이를 입력하세요:"), gender = input("성별을 입력하세요:"))
# Out:
# 이름을 입력하세요:이형운
# 나이를 입력하세요:20
# 성별을 입력하세요:남자
# 이름:이형운, 나이:20, 성별:남자

# %% [markdown]
# ---

# %% [markdown]
# [문제 5] 두 개의 정수를 받아 합을 반환하는 함수 add를 작성하세요. 매개변수와 반환값에 타입 어노테이션을 추가하세요.

# %%
def add(x: int,y: int) -> int:
    return x + y

# %% [markdown]
# [문제 6] 0부터 시작하여 n까지의 숫자 중에서 홀수만 생성하는 제너레이터 odd_numbers를 작성하세요.

# %%
def odd_numbers(n):
    for i in range(n + 1):
        if i % 2 == 1:
            yield i
for i in odd_numbers(10):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# *   항목 추가
# *   항목 추가

# %% [markdown]
# ---

# %% [markdown]
# [문제 7] 두 숫자를 더하는 람다 함수를 작성하고, 이를 변수에 할당한 후 사용하세요.

# %%
add_lamda = lambda x, y: x + y
num1 = int(input("첫번째 숫자를 입력하세요: "))
num2 = int(input("두번째 숫자를 입력하세요: "))
user_result = add_lamda(num1, num2)
print(f"람다 함수를 이용한 두 숫자의 합: {user_result}")
# Out:
# 첫번째 숫자를 입력하세요: 10
# 두번째 숫자를 입력하세요: 20
# 람다 함수를 이용한 두 숫자의 합: 30

# %% [markdown]
# ---

# %% [markdown]
# [문제 8] 사용자로부터 3개의 숫자를 입력받아, 이를 튜플로 만든 후 최소값과 최대값을 출력하는 함수 min_max를 작성하세요.

# %%
def min_max():
    num1 = int(input("첫번째 숫자를 입력하세요: "))
    num2 = int(input("두번째 숫자를 입력하세요: "))
    num3 = int(input("세번째 숫자를 입력하세요: "))
    num_tuple = (num1, num2, num3)
    print(f"최소값: {min(num_tuple)}, 최대값: {max(num_tuple)}")
min_max()
# Out:
# 첫번째 숫자를 입력하세요: 1
# 두번째 숫자를 입력하세요: 2
# 세번째 숫자를 입력하세요: 3
# 최소값: 1, 최대값: 3

# %% [markdown]
# ---

# %% [markdown]
# [문제 9] 주어진 숫자가 짝수인지 확인하는 함수 is_even을 작성하세요. 짝수라면 True를, 아니라면 False를 반환하세요. 함수 내에서 조기 리턴을 활용하세요.

# %%
def is_even(num):
    if num % 2 == 0:
        return True
    else:
        return False
num = int(input("숫자를 입력하세요: "))
print(is_even(num))
# Out:
# 숫자를 입력하세요: 3
# False

# %% [markdown]
# ---

# %% [markdown]
# [문제 10] 팩토리얼을 계산하는 재귀 함수 factorial을 작성하세요.

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)
num = int(input("숫자를 입력하세요: "))
print(factorial(num))
# Out:
# 숫자를 입력하세요: 7
# 5040

# %% [markdown]
# ---

# %% [markdown]
# [문제 11] 문자열 리스트를 받아, 각 문자열의 길이를 출력하는 함수 print_lengths를 작성하세요.

# %%
def print_lengths(str_list):
    for str in str_list:
        print(f"{str}: {len(str)}")
str_list = input("문자열을 ,로 구분하여 입력하세요: ").split(',')
print_lengths(str_list)
# Out:
# 문자열을 ,로 구분하여 입력하세요: 안녕하세요, 제이름은, 김덕배입니다
# 안녕하세요: 5
#  제이름은: 5
#  김덕배입니다: 7

# %% [markdown]
# ---

# %% [markdown]
# [문제 12] 두 문자열을 받아서 긴 문자열을 반환하는 함수 longer_string을 작성하세요. 만약 두 문자열의 길이가 같다면, 첫 번째 문자열을 반환하세요.

# %%
def longer_string(str1, str2):
    if len(str1) >= len(str2):
        return str1
    else:
        return str2
str1 = input("첫번째 문자열을 입력해주세요: ")
str2 = input("두번째 문자열을 입력해주세요: ")
str = longer_string(str1, str2)
print(f"더 긴 문자열은: {str}")
# Out:
# 첫번째 문자열을 입력해주세요: ㅎㅇ
# 두번째 문자열을 입력해주세요: ㅎㅇㅇ
# 더 긴 문자열은: ㅎㅇㅇ
